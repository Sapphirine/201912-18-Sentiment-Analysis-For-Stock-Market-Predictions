# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import numpy as np
from datetime import datetime
import pandas_datareader.data as web
import yfinance as yf
from statsmodels.tsa.stattools import grangercausalitytests
# from pylab import rcParams
# from pmdarima.arima import auto_arima
import os
import matplotlib.pyplot as plt
import pyflux as pf
# import statsmodels.api as sm
# # import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)
# warnings.filterwarnings("ignore")

# %%
# Load our dataset which has should have format [date, tweet, sentiment scores in a column labeled compound]
# Fine to have more columns, but we need at least these three

# In this case our compound column is composed of sentiment scores from VADER
# In our testing this method performed better than GCP NLP, IBM-Watson NLU, and TextBlob  
# https://github.com/cjhutto/vaderSentiment
non_neutral_df = pd.read_csv("data/Total_Processed_TwitterData_oct18-oct19.csv")

# When ready for collab:
non_neutral_df = pd.read_csv("https://peyck.es/BDA/Total_Processed_TwitterData_oct18-oct19.csv")

# %%
# Across all sentiment analysis tools, there are a large number of "neutral" tweets
# These will compromise performance later so we will filter out all sentiment scores == 0

# Formatting: we want to end with an index of dates and all tweets with nonzero sentiment
non_neutral_df = non_neutral_df.drop(columns={'Unnamed: 0'}, axis=1)
non_neutral_df = non_neutral_df[non_neutral_df['compound']!=0]
non_neutral_df['date'] = pd.to_datetime(non_neutral_df.date)
non_neutral_df.head()
# Out:
#                   date                                               text  \
# 0  2019-04-01 00:00:00  STEAL: Over 50% OFF + free shipping on the Nik...
# 1  2019-04-01 00:00:00  Check out #Nike Dry Fit Shorts Women's Tempo N...
# 4  2019-04-01 00:00:00  @MichaelAvenatti He aint dumb he is not showin...
# 6  2019-04-01 00:00:00  NIKE AIR VAPORMAX FLYKNIT 3 "LIMITED EDITION f...
# 10 2019-04-01 00:01:00  Perfect time for Nike to amp up their @Kaepern...
#
#                                        polarity_value    neg    pos    neu  \
# 0   {'neg': 0.169, 'neu': 0.689, 'pos': 0.142, 'co...  0.169  0.142  0.689
# 1   {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'comp...  0.000  0.206  0.794
# 4   {'neg': 0.166, 'neu': 0.758, 'pos': 0.076, 'co...  0.166  0.076  0.758
# 6   {'neg': 0.208, 'neu': 0.792, 'pos': 0.0, 'comp...  0.208  0.000  0.792
# 10  {'neg': 0.0, 'neu': 0.73, 'pos': 0.27, 'compou...  0.000  0.270  0.730
#
#     compound
# 0    -0.1613
# 1     0.6369
# 4    -0.2955
# 6    -0.3885
# 10    0.5719

# %%
# We will only need date and compound sentiment scores for this model
# Make a dataframe with only date and compound sentiment scores
data_scoresOnly = []
data_scoresOnly = non_neutral_df[['date','compound']].copy()
data_scoresOnly['date'] = pd.to_datetime(data_scoresOnly.date)
data_scoresOnly.set_index('date')
print()

# %%
# There is no live stock data on weekends, so let's only look at weekdays
# Make a new dataframe of only weekdays
data_weekdayScores = data_scoresOnly.copy()
data_weekdayScores['weekday'] = data_weekdayScores['date'].apply(lambda x: x.weekday())

# Because we are looking at a long range forecast, we are going to average sentiment over full days
data_weekdayScores = data_weekdayScores.resample('D', on='date').mean()
data_weekdayScores = data_weekdayScores[data_weekdayScores['weekday'] < 5]
data_weekdayScores = data_weekdayScores[[ 'compound']]

# %%
# At this point we have a dataframe with sentiment scores for all weekdays from the past year
# Get Financial Data for modeling so we can begin building our models
start=datetime(2018,10,1)
end=datetime(2019,10,30)
df = web.DataReader(['NKE'], 'yahoo', start, end)
df['datetime']=df.index
df['datetime'] = pd.to_datetime(df['datetime'])
finance_df=df.set_index("datetime").copy()
finance_df['date']=df['datetime']
# finance_df.info()

# %%
# For now, let's look only at Adjusted Close
# Make a new data frame with Adjusted Close, and our compound sentiment scores
data_weekdayScores['AdjClose'] = finance_df.iloc[:,0]
data_weekdayScores['AdjClose'] = data_weekdayScores['AdjClose'].fillna(method='bfill')
model_df = data_weekdayScores.copy()
model_df = model_df.fillna(method='ffill')
# model_df.head(10)

# %%
#Plot to see if there are any immediately visible relationships 
fig, ax1 = plt.subplots(figsize=(18,10))
ax1.set_xlabel('Date')
ax1.set_ylabel('Sentiment')
ax1.plot(model_df.index, model_df['compound'], color = 'r')
ax1.tick_params(axis='y', labelcolor='r')

ax2 = ax1.twinx()
ax2.set_ylabel('Closing Price')
ax2.plot(model_df.index, model_df['AdjClose'], color = 'b')
ax2.tick_params(axis='y', labelcolor='b')
fig.tight_layout()
plt.show()

# %%
# Tough to say at first glance: The largest negative spike in sentimennt occurs the same day
# as a significant price drop but the second largest negative spike happens a date range with
# a significant price increase

# %%
# Causality Testing from statsmodels
# https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.grangercausalitytests.html


# A low P value suggests that your sample provides enough evidence that you can reject the null hypothesis 
# for the entire population.

# The Null hypothesis for grangercausalitytests is that the time series in the second column, x2, does NOT 
# Granger cause the time series in the first column, x1. 

causality_array = model_df.to_numpy().copy()

#Swapping the columns because Granger analysis is the measure of whether time series in col 2 causes col 1
causality_array[:,[0, 1]] = causality_array[:,[1, 0]]
causality = grangercausalitytests(causality_array, maxlag=50)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9034  , p=0.1688  , df_denom=274, df_num=1
# ssr based chi2 test:   chi2=1.9243  , p=0.1654  , df=1
# likelihood ratio test: chi2=1.9176  , p=0.1661  , df=1
# parameter F test:         F=1.9034  , p=0.1688  , df_denom=274, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6595  , p=0.1922  , df_denom=271, df_num=2
# ssr based chi2 test:   chi2=3.3802  , p=0.1845  , df=2
# likelihood ratio test: chi2=3.3596  , p=0.1864  , df=2
# parameter F test:         F=1.6595  , p=0.1922  , df_denom=271, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8669  , p=0.1355  , df_denom=268, df_num=3
# ssr based chi2 test:   chi2=5.7469  , p=0.1246  , df=3
# likelihood ratio test: chi2=5.6876  , p=0.1278  , df=3
# parameter F test:         F=1.8669  , p=0.1355  , df_denom=268, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1640  , p=0.0734  , df_denom=265, df_num=4
# ssr based chi2 test:   chi2=8.9498  , p=0.0624  , df=4
# likelihood ratio test: chi2=8.8067  , p=0.0661  , df=4
# parameter F test:         F=2.1640  , p=0.0734  , df_denom=265, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9677  , p=0.0838  , df_denom=262, df_num=5
# ssr based chi2 test:   chi2=10.2517 , p=0.0684  , df=5
# likelihood ratio test: chi2=10.0639 , p=0.0734  , df=5
# parameter F test:         F=1.9677  , p=0.0838  , df_denom=262, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6615  , p=0.1308  , df_denom=259, df_num=6
# ssr based chi2 test:   chi2=10.4696 , p=0.1062  , df=6
# likelihood ratio test: chi2=10.2731 , p=0.1136  , df=6
# parameter F test:         F=1.6615  , p=0.1308  , df_denom=259, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4175  , p=0.1984  , df_denom=256, df_num=7
# ssr based chi2 test:   chi2=10.5038 , p=0.1618  , df=7
# likelihood ratio test: chi2=10.3054 , p=0.1719  , df=7
# parameter F test:         F=1.4175  , p=0.1984  , df_denom=256, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9983  , p=0.4378  , df_denom=253, df_num=8
# ssr based chi2 test:   chi2=8.5231  , p=0.3841  , df=8
# likelihood ratio test: chi2=8.3914  , p=0.3962  , df=8
# parameter F test:         F=0.9983  , p=0.4378  , df_denom=253, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9574  , p=0.4760  , df_denom=250, df_num=9
# ssr based chi2 test:   chi2=9.2714  , p=0.4126  , df=9
# likelihood ratio test: chi2=9.1152  , p=0.4267  , df=9
# parameter F test:         F=0.9574  , p=0.4760  , df_denom=250, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2498  , p=0.2600  , df_denom=247, df_num=10
# ssr based chi2 test:   chi2=13.5602 , p=0.1940  , df=10
# likelihood ratio test: chi2=13.2283 , p=0.2112  , df=10
# parameter F test:         F=1.2498  , p=0.2600  , df_denom=247, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.1437  , p=0.3279  , df_denom=244, df_num=11
# ssr based chi2 test:   chi2=13.7664 , p=0.2462  , df=11
# likelihood ratio test: chi2=13.4233 , p=0.2666  , df=11
# parameter F test:         F=1.1437  , p=0.3279  , df_denom=244, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.0608  , p=0.3942  , df_denom=241, df_num=12
# ssr based chi2 test:   chi2=14.0503 , p=0.2975  , df=12
# likelihood ratio test: chi2=13.6918 , p=0.3208  , df=12
# parameter F test:         F=1.0608  , p=0.3942  , df_denom=241, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=0.9696  , p=0.4821  , df_denom=238, df_num=13
# ssr based chi2 test:   chi2=14.0346 , p=0.3714  , df=13
# likelihood ratio test: chi2=13.6755 , p=0.3971  , df=13
# parameter F test:         F=0.9696  , p=0.4821  , df_denom=238, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=0.9445  , p=0.5116  , df_denom=235, df_num=14
# ssr based chi2 test:   chi2=14.8551 , p=0.3881  , df=14
# likelihood ratio test: chi2=14.4522 , p=0.4166  , df=14
# parameter F test:         F=0.9445  , p=0.5116  , df_denom=235, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=0.8803  , p=0.5869  , df_denom=232, df_num=15
# ssr based chi2 test:   chi2=14.9697 , p=0.4536  , df=15
# likelihood ratio test: chi2=14.5592 , p=0.4836  , df=15
# parameter F test:         F=0.8803  , p=0.5869  , df_denom=232, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=0.9289  , p=0.5368  , df_denom=229, df_num=16
# ssr based chi2 test:   chi2=17.0039 , p=0.3853  , df=16
# likelihood ratio test: chi2=16.4749 , p=0.4203  , df=16
# parameter F test:         F=0.9289  , p=0.5368  , df_denom=229, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=0.9441  , p=0.5229  , df_denom=226, df_num=17
# ssr based chi2 test:   chi2=18.5352 , p=0.3559  , df=17
# likelihood ratio test: chi2=17.9066 , p=0.3948  , df=17
# parameter F test:         F=0.9441  , p=0.5229  , df_denom=226, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=1.3004  , p=0.1889  , df_denom=223, df_num=18
# ssr based chi2 test:   chi2=27.2900 , p=0.0737  , df=18
# likelihood ratio test: chi2=25.9508 , p=0.1009  , df=18
# parameter F test:         F=1.3004  , p=0.1889  , df_denom=223, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.2115  , p=0.2497  , df_denom=220, df_num=19
# ssr based chi2 test:   chi2=27.0988 , p=0.1024  , df=19
# likelihood ratio test: chi2=25.7729 , p=0.1366  , df=19
# parameter F test:         F=1.2115  , p=0.2497  , df_denom=220, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.1688  , p=0.2836  , df_denom=217, df_num=20
# ssr based chi2 test:   chi2=27.7923 , p=0.1144  , df=20
# likelihood ratio test: chi2=26.3949 , p=0.1532  , df=20
# parameter F test:         F=1.1688  , p=0.2836  , df_denom=217, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=1.1877  , p=0.2639  , df_denom=214, df_num=21
# ssr based chi2 test:   chi2=29.9538 , p=0.0929  , df=21
# likelihood ratio test: chi2=28.3330 , p=0.1310  , df=21
# parameter F test:         F=1.1877  , p=0.2639  , df_denom=214, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=1.2428  , p=0.2149  , df_denom=211, df_num=22
# ssr based chi2 test:   chi2=33.1719 , p=0.0595  , df=22
# likelihood ratio test: chi2=31.1920 , p=0.0923  , df=22
# parameter F test:         F=1.2428  , p=0.2149  , df_denom=211, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=1.2429  , p=0.2117  , df_denom=208, df_num=23
# ssr based chi2 test:   chi2=35.0450 , p=0.0515  , df=23
# likelihood ratio test: chi2=32.8370 , p=0.0839  , df=23
# parameter F test:         F=1.2429  , p=0.2117  , df_denom=208, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=1.3247  , p=0.1507  , df_denom=205, df_num=24
# ssr based chi2 test:   chi2=39.3909 , p=0.0248  , df=24
# likelihood ratio test: chi2=36.6196 , p=0.0477  , df=24
# parameter F test:         F=1.3247  , p=0.1507  , df_denom=205, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=1.4678  , p=0.0780  , df_denom=202, df_num=25
# ssr based chi2 test:   chi2=45.9606 , p=0.0065  , df=25
# likelihood ratio test: chi2=42.2313 , p=0.0170  , df=25
# parameter F test:         F=1.4678  , p=0.0780  , df_denom=202, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=1.3942  , p=0.1062  , df_denom=199, df_num=26
# ssr based chi2 test:   chi2=45.9036 , p=0.0094  , df=26
# likelihood ratio test: chi2=42.1699 , p=0.0236  , df=26
# parameter F test:         F=1.3942  , p=0.1062  , df_denom=199, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=1.3149  , p=0.1477  , df_denom=196, df_num=27
# ssr based chi2 test:   chi2=45.4659 , p=0.0145  , df=27
# likelihood ratio test: chi2=41.7863 , p=0.0345  , df=27
# parameter F test:         F=1.3149  , p=0.1477  , df_denom=196, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=1.2636  , p=0.1813  , df_denom=193, df_num=28
# ssr based chi2 test:   chi2=45.8302 , p=0.0181  , df=28
# likelihood ratio test: chi2=42.0812 , p=0.0426  , df=28
# parameter F test:         F=1.2636  , p=0.1813  , df_denom=193, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=1.2582  , p=0.1830  , df_denom=190, df_num=29
# ssr based chi2 test:   chi2=47.8179 , p=0.0153  , df=29
# likelihood ratio test: chi2=43.7408 , p=0.0388  , df=29
# parameter F test:         F=1.2582  , p=0.1830  , df_denom=190, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=1.2468  , p=0.1898  , df_denom=187, df_num=30
# ssr based chi2 test:   chi2=49.6046 , p=0.0136  , df=30
# likelihood ratio test: chi2=45.2196 , p=0.0368  , df=30
# parameter F test:         F=1.2468  , p=0.1898  , df_denom=187, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=1.3121  , p=0.1394  , df_denom=184, df_num=31
# ssr based chi2 test:   chi2=54.6008 , p=0.0055  , df=31
# likelihood ratio test: chi2=49.3299 , p=0.0195  , df=31
# parameter F test:         F=1.3121  , p=0.1394  , df_denom=184, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=1.3378  , p=0.1211  , df_denom=181, df_num=32
# ssr based chi2 test:   chi2=58.1847 , p=0.0031  , df=32
# likelihood ratio test: chi2=52.2267 , p=0.0134  , df=32
# parameter F test:         F=1.3378  , p=0.1211  , df_denom=181, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=1.4124  , p=0.0813  , df_denom=178, df_num=33
# ssr based chi2 test:   chi2=64.1544 , p=0.0009  , df=33
# likelihood ratio test: chi2=56.9828 , p=0.0059  , df=33
# parameter F test:         F=1.4124  , p=0.0813  , df_denom=178, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=1.3347  , p=0.1189  , df_denom=175, df_num=34
# ssr based chi2 test:   chi2=63.2702 , p=0.0017  , df=34
# likelihood ratio test: chi2=56.2565 , p=0.0096  , df=34
# parameter F test:         F=1.3347  , p=0.1189  , df_denom=175, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=1.3443  , p=0.1114  , df_denom=172, df_num=35
# ssr based chi2 test:   chi2=66.4733 , p=0.0010  , df=35
# likelihood ratio test: chi2=58.7599 , p=0.0072  , df=35
# parameter F test:         F=1.3443  , p=0.1114  , df_denom=172, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=1.3601  , p=0.1009  , df_denom=169, df_num=36
# ssr based chi2 test:   chi2=70.1145 , p=0.0006  , df=36
# likelihood ratio test: chi2=61.5726 , p=0.0050  , df=36
# parameter F test:         F=1.3601  , p=0.1009  , df_denom=169, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=1.3487  , p=0.1055  , df_denom=166, df_num=37
# ssr based chi2 test:   chi2=72.4460 , p=0.0004  , df=37
# likelihood ratio test: chi2=63.3421 , p=0.0045  , df=37
# parameter F test:         F=1.3487  , p=0.1055  , df_denom=166, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=1.3442  , p=0.1065  , df_denom=163, df_num=38
# ssr based chi2 test:   chi2=75.2119 , p=0.0003  , df=38
# likelihood ratio test: chi2=65.4255 , p=0.0037  , df=38
# parameter F test:         F=1.3442  , p=0.1065  , df_denom=163, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=1.3564  , p=0.0983  , df_denom=160, df_num=39
# ssr based chi2 test:   chi2=79.0213 , p=0.0002  , df=39
# likelihood ratio test: chi2=68.2715 , p=0.0026  , df=39
# parameter F test:         F=1.3564  , p=0.0983  , df_denom=160, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=1.2422  , p=0.1759  , df_denom=157, df_num=40
# ssr based chi2 test:   chi2=75.3223 , p=0.0006  , df=40
# likelihood ratio test: chi2=65.4409 , p=0.0068  , df=40
# parameter F test:         F=1.2422  , p=0.1759  , df_denom=157, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=1.3328  , p=0.1090  , df_denom=154, df_num=41
# ssr based chi2 test:   chi2=84.0973 , p=0.0001  , df=41
# likelihood ratio test: chi2=71.9731 , p=0.0020  , df=41
# parameter F test:         F=1.3328  , p=0.1090  , df_denom=154, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=1.6838  , p=0.0122  , df_denom=151, df_num=42
# ssr based chi2 test:   chi2=110.5271, p=0.0000  , df=42
# likelihood ratio test: chi2=90.6545 , p=0.0000  , df=42
# parameter F test:         F=1.6838  , p=0.0122  , df_denom=151, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=1.7080  , p=0.0100  , df_denom=148, df_num=43
# ssr based chi2 test:   chi2=116.6165, p=0.0000  , df=43
# likelihood ratio test: chi2=94.6946 , p=0.0000  , df=43
# parameter F test:         F=1.7080  , p=0.0100  , df_denom=148, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=1.6320  , p=0.0165  , df_denom=145, df_num=44
# ssr based chi2 test:   chi2=115.8833, p=0.0000  , df=44
# likelihood ratio test: chi2=94.1332 , p=0.0000  , df=44
# parameter F test:         F=1.6320  , p=0.0165  , df_denom=145, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=1.6130  , p=0.0184  , df_denom=142, df_num=45
# ssr based chi2 test:   chi2=119.1041, p=0.0000  , df=45
# likelihood ratio test: chi2=96.2030 , p=0.0000  , df=45
# parameter F test:         F=1.6130  , p=0.0184  , df_denom=142, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=1.6246  , p=0.0167  , df_denom=139, df_num=46
# ssr based chi2 test:   chi2=124.7290, p=0.0000  , df=46
# likelihood ratio test: chi2=99.8155 , p=0.0000  , df=46
# parameter F test:         F=1.6246  , p=0.0167  , df_denom=139, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=1.5438  , p=0.0282  , df_denom=136, df_num=47
# ssr based chi2 test:   chi2=123.2440, p=0.0000  , df=47
# likelihood ratio test: chi2=98.7683 , p=0.0000  , df=47
# parameter F test:         F=1.5438  , p=0.0282  , df_denom=136, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=1.5547  , p=0.0259  , df_denom=133, df_num=48
# ssr based chi2 test:   chi2=129.0534, p=0.0000  , df=48
# likelihood ratio test: chi2=102.4401, p=0.0000  , df=48
# parameter F test:         F=1.5547  , p=0.0259  , df_denom=133, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=1.6695  , p=0.0117  , df_denom=130, df_num=49
# ssr based chi2 test:   chi2=144.1012, p=0.0000  , df=49
# likelihood ratio test: chi2=111.7813, p=0.0000  , df=49
# parameter F test:         F=1.6695  , p=0.0117  , df_denom=130, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=1.6464  , p=0.0136  , df_denom=127, df_num=50
# ssr based chi2 test:   chi2=147.7894, p=0.0000  , df=50
# likelihood ratio test: chi2=113.9278, p=0.0000  , df=50
# parameter F test:         F=1.6464  , p=0.0136  , df_denom=127, df_num=50

# %%
# Start Modeling
# Our best performing model is ARIMAX 
# https://github.com/RJT1990/pyflux/blob/master/pyflux/arma/arimax.py
# Autoregressive Integrated Moving Average Exogenous Variable Models
# In this case our exogendous variable is sentiment

# Create a train test split for our model
# The training will occur on all tweets from Oct 2018- August 14th 2019
train_ARIMAX = model_df[:int(0.8*(len(model_df)))].copy()
test_ARIMAX = model_df[int(0.8*(len(model_df))):].copy()

model_arimax = pf.ARIMAX(data=train_ARIMAX,formula='AdjClose~1+compound',ar=50, ma=5, integ=0,family=pf.Normal())
model_arimax_fit = model_arimax.fit("MLE")

# %%
#Let's take a quick look at our model with training data
model_arimax.plot_fit()

# %%
# Now let's predict our test test values
# Reminder: At this point our model has not seen any data past August 14th

# Start with a quick plot of the prediction with prediction intervals
# Darker values mean a higher prediction
model_arimax.plot_predict(h=20, oos_data=test_ARIMAX,past_values=100, figsize=(15,5), intervals=True)

# %%
# Seems realistic, but let's take a closer look
# Get our array of values so we can plot with the real values
prediction = model_arimax.predict(h=56, oos_data=train_ARIMAX,intervals=True)

# %%
#Take a subset of our real data so we can plot against our prediction over the same range
true_data = model_df.loc[prediction.index[0]:prediction.index[-1]].copy()

# %%
# Now let's plot our predictions on test data vs real data over the date range to get a better idea of accuracy
fig, ax1 = plt.subplots(figsize=(18,6))
ax1.set_xlabel('Date')
ax1.set_ylabel('Real')
ax1.plot(true_data.index, true_data.iloc[0:56,1], color = 'r')
ax1.tick_params(axis='y', labelcolor='r')

ax2 = ax1.twinx()
ax2.set_ylabel('predicted')
ax2.plot(prediction.index, prediction.iloc[0:56,0], color = 'b')
ax2.tick_params(axis='y', labelcolor='b')
plt.title("Real and Predicted Adjusted Close ")
plt.show()

# %%
# Although there are some differences in the true price, it is easy to see that our model could be used as
# a useful tool when deciding whether to buy or sell.

# %%
# But how much of the model's success is due to sentiment?
# Let's predict using only historical stock data

# %%
# Lets keep all parameters the same but leave out sentiment 
# Duplicate our train test split for our stock only model
train_ARIMA = model_df[:int(0.8*(len(model_df)))].copy()
test_ARIMA = model_df[int(0.8*(len(model_df))):].copy()

model_arima = pf.ARIMA(data=train_ARIMA,ar=50, ma=5, integ=0,family=pf.Normal())
model_arima_fit = model_arima.fit("MLE")
# model_arimax_fit.summary()


# Get our array of Predicted values so we can plot with the real values
prediction_ARIMA = model_arima.predict(h=56,intervals=True)
# Make a copy of real financial data from the predicted period
true_data_ARIMA = model_df.loc[prediction.index[0]:prediction_ARIMA.index[-1]].copy()

# %%
# Now let's plot our predictions vs real data over the date range to get a better idea
fig, ax1 = plt.subplots(figsize=(18,6))
ax1.set_xlabel('Date')
ax1.set_ylabel('Real')
ax1.plot(true_data_ARIMA.index, true_data_ARIMA.iloc[0:56,1], color = 'r')
ax1.tick_params(axis='y', labelcolor='r')

ax2 = ax1.twinx()
ax2.set_ylabel('predicted')
ax2.plot(prediction_ARIMA.index, prediction_ARIMA.iloc[0:56,0], color = 'b')
ax2.tick_params(axis='y', labelcolor='b')
plt.title("Real and Predicted Adjusted Close Based solely on Historical Price")
plt.show()

# %%
# Was our prediction on October data just a fluke?
# Today is December 1st 2019, so we can predict the month of November
# No tweets have been gathered for the month of November, so let's see what happens when we 
# model with a full year of sentiment

# %%
# Keeping all the same parameters as our first prediction
train_ARIMAX_FullYear = model_df.copy()

model_arimax_FullYear = pf.ARIMAX(data=train_ARIMAX_FullYear,formula='AdjClose~1+compound',ar=50, ma=5, integ=0,family=pf.Normal())
model_arimax_FullYear_fit = model_arimax_FullYear.fit("MLE")

# %%
model_arimax_FullYear.plot_fit()

# %%
# We want to test over the month of november so let's create an empty dataframe with weekday indicies
test_ARIMAX_FullYear = pd.DatetimeIndex(start ='2019-11-01', end='2019-11-30', freq='B')
df = pd.DataFrame(test_ARIMAX_FullYear,columns={'Date'})
df = df.set_index('Date')
test_ARIMAX_FullYear = df.copy()

# %%
model_arimax_FullYear.plot_predict(h=20, oos_data=train_ARIMAX_FullYear,past_values=100, figsize=(15,5), intervals=True)

# %%
# At this point we have a dataframe with sentiment scores for all weekdays from the past year
# Get Financial Data for modeling so we can begin building our models
start=datetime(2019,11,1)
end=datetime(2019,12,26)
df = web.DataReader(['NKE'], 'yahoo', start, end)
df['datetime']=df.index
df['datetime'] = pd.to_datetime(df['datetime'])
finance_df=df.set_index("datetime").copy()
finance_df['date']=df['datetime']
# finance_df.info()

# %%
# Get our array of values so we can plot with the real values
prediction_Nov = model_arimax_FullYear.predict(h=56, oos_data=train_ARIMAX_FullYear,intervals=True)

# %%
# prediction_Nov is a prediction through December 26th, but we can only compare through Dec12th
# We can combine values to one dataframe so we can easily update when future stock data is available

total_df = finance_df['Adj Close'].copy()
total_df = total_df.join(prediction_Nov, how='left')
# total_df.head(50)

# %%
# Now let's plot our predictions on test data vs real data over the date range to get a better idea of accuracy
fig, ax1 = plt.subplots(figsize=(18,6))
ax1.set_xlabel('Date')
ax1.set_ylabel('Real')
#Real adjusted close price 
ax1.plot(total_df.index, total_df.iloc[:,0], color = 'r')
ax1.tick_params(axis='y', labelcolor='r')

ax2 = ax1.twinx()
ax2.set_ylabel('predicted')
ax2.plot(total_df.index, total_df.iloc[:,1], color = 'b')
ax2.tick_params(axis='y', labelcolor='b')
plt.title("Real and Predicted Adjusted Close ")
plt.show()

# %%
# So Should you Buy or Sell?
prediction_Nov[-10:]
# Out:
#              AdjClose  1% Prediction Interval  5% Prediction Interval  \
# date
# 2019-12-13  95.528767               86.016264               88.800702
# 2019-12-16  94.901213               85.280652               88.161117
# 2019-12-17  95.575147               85.721263               88.797587
# 2019-12-18  95.613810               86.018458               88.770116
# 2019-12-19  95.485361               85.721800               88.639465
# 2019-12-20  95.864899               86.076828               89.012309
# 2019-12-23  95.654467               85.800882               88.840375
# 2019-12-24  95.454020               85.605690               88.551918
# 2019-12-25  95.932767               86.162266               89.041329
# 2019-12-26  96.457322               86.704815               89.519220
#
#             95% Prediction Interval  99% Prediction Interval
# date
# 2019-12-13               102.286375               105.199964
# 2019-12-16               101.717077               104.626472
# 2019-12-17               102.347680               105.247985
# 2019-12-18               102.558358               105.360626
# 2019-12-19               102.361399               105.105845
# 2019-12-20               102.831830               105.653932
# 2019-12-23               102.613644               105.420523
# 2019-12-24               102.372542               105.247382
# 2019-12-25               102.927384               105.817098
# 2019-12-26               103.469891               106.280046

# %%
# Wait until Monday! (But don't buy too much)
